# %%
import pandas as pd

# %matplotlib inline

# %%
path = "cursos-prouni.csv"

df = pd.read_csv(path)

df.head()
# Out:
#           grau     turno  mensalidade  bolsa_integral_cotas  \
# 0  Bacharelado  Integral      9999.99                  15.0
# 1  Bacharelado   Noturno      9836.40                   1.0
# 2  Bacharelado  Integral      9715.61                   2.0
# 3  Bacharelado   Noturno      9689.34                   3.0
# 4  Bacharelado  Integral      9674.34                   4.0
#
#    bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 0                  14.0                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   5.0                  6.0                 10.0
# 3                   2.0                  NaN                  NaN
# 4                   1.0                  5.0                  2.0
#
#           curso_id curso_busca  cidade_busca uf_busca     cidade_filtro  \
# 0     706710394154    Medicina  Campo Grande       MS  NTAwMjAwNDAyNzA0
# ...

# %%
#CONTAGEM DE TIPOS DE GRADUAÇÃO DOS CURSOS
df['grau'].value_counts()
# Out:
# grau
# Bacharelado     19165
# Tecnológico     13480
# Licenciatura     8802
# Name: count, dtype: int64

# %%
#CHECAR TIPOS DAS SERIES

df.dtypes
# Out:
# grau                     object
# turno                    object
# mensalidade             float64
# bolsa_integral_cotas    float64
# bolsa_integral_ampla    float64
# bolsa_parcial_cotas     float64
# bolsa_parcial_ampla     float64
# curso_id                  int64
# curso_busca              object
# cidade_busca             object
# uf_busca                 object
# cidade_filtro            object
# universidade_nome        object
# campus_nome              object
# campus_id                 int64
# nome                     object
# nota_integral_ampla     float64
# nota_integral_cotas     float64
# nota_parcial_ampla      float64
# nota_parcial_cotas      float64
# dtype: object

# %%
#VERIFICAR TAMANHO DO DATAFRAME (LINHAS X COLUNAS)

df.shape
# Out:
# (41447, 20)

# %%
#ANALISE MATEMÁTICA AUTOMÁTICA GERAL

df.describe()
# Out:
#         mensalidade  bolsa_integral_cotas  bolsa_integral_ampla  \
# count  41447.000000          32520.000000          25404.000000
# mean     622.636966              1.535394              2.513541
# std      606.442296              2.191578              3.019549
# min      139.000000              0.000000              1.000000
# 25%      278.000000              0.000000              1.000000
# 50%      393.350000              1.000000              1.000000
# 75%      825.000000              2.000000              3.000000
# max     9999.990000             58.000000             67.000000
#
#        bolsa_parcial_cotas  bolsa_parcial_ampla      curso_id     campus_id  \
# count          8828.000000         13041.000000  4.144700e+04  4.144700e+04
# mean              1.873018             8.632544  4.207360e+13  6.786530e+05
# std               2.336403            18.372991  6.061552e+13  6.398410e+05
# min               1.000000             1.000000  2.248801e+07  2.240000e+02
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41447 entries, 0 to 41446
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   grau                  41447 non-null  object
#  1   turno                 41447 non-null  object
#  2   mensalidade           41447 non-null  float64
#  3   bolsa_integral_cotas  32520 non-null  float64
#  4   bolsa_integral_ampla  25404 non-null  float64
#  5   bolsa_parcial_cotas   8828 non-null   float64
#  6   bolsa_parcial_ampla   13041 non-null  float64
#  7   curso_id              41447 non-null  int64
#  8   curso_busca           41447 non-null  object
#  9   cidade_busca          41447 non-null  object
#  10  uf_busca              41447 non-null  object
#  11  cidade_filtro         41447 non-null  object
#  12  universidade_nome     41447 non-null  object
#  13  campus_nome           41447 non-null  object
#  14  campus_id             41447 non-null  int64
# ...

# %%
#CRIANDO SUBCONJUNTO DO DATAFRAME ORIGINAL SELECIONANDO APENAS ONDE NA COLUNA MENSALIDADE O VALOR SEJA O MÁXIMO DA COLUNA
df[df['mensalidade'] == df['mensalidade'].max()][['grau','curso_busca','cidade_busca','uf_busca','mensalidade']]
# Out:
#           grau curso_busca  cidade_busca uf_busca  mensalidade
# 0  Bacharelado    Medicina  Campo Grande       MS      9999.99

# %%
#CURSOS MAIS BARATOS DO BRASIL

df[df['mensalidade'] == df['mensalidade'].min()][['grau','curso_busca','cidade_busca','uf_busca','mensalidade']]
# Out:
#               grau                 curso_busca cidade_busca uf_busca  \
# 41444  Tecnológico  Gestão de Recursos Humanos     Brasilia       DF
# 41445  Bacharelado              Serviço Social      Vitoria       ES
# 41446  Tecnológico            Gestão Ambiental     Santarem       PA
#
#        mensalidade
# 41444        139.0
# 41445        139.0
# 41446        139.0

# %%
#MENSALIDADE MAIS CARA POR UF, DO MAIS CARO PRO MAIS BARATO

df.groupby('uf_busca')['mensalidade'].max().sort_values(ascending=False)
# Out:
# uf_busca
# MS    9999.99
# CE    9836.40
# SP    9715.61
# AC    9674.34
# MG    9350.00
# MT    9208.00
# BA    9048.00
# RJ    9023.07
# PA    8508.54
# PR    8466.72
# PI    8402.00
# PB    8350.00
# RS    8329.95
# MA    8281.38
# TO    7800.00
# AL    7290.00
# PE    7250.00
# SC    6922.15
# RO    6909.97
# DF    6757.92
# RN    6505.09
# SE    6490.00
# GO    6484.47
# ES    6022.28
# AP    3607.62
# AM    2127.05
# RR    1463.05
# Name: mensalidade, dtype: float64

# %%
#FAZER O MESMO QUE O ANTERIOR MAS MOSTRANDO TODAS COLUNAS (O loc retorna a LINHA de todos os dados e não só os utilizados para filtragem)

df.loc[df.groupby('uf_busca')['mensalidade'].idxmax()].head()
# Out:
#             grau     turno  mensalidade  bolsa_integral_cotas  \
# 4    Bacharelado  Integral      9674.34                   4.0
# 67   Bacharelado  Integral      7290.00                   5.0
# 627  Bacharelado  Matutino      2127.05                   4.0
# 202  Bacharelado   Noturno      3607.62                   0.0
# 9    Bacharelado  Integral      9048.00                  13.0
#
#      bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 4                     1.0                  5.0                  2.0
# 67                    2.0                  NaN                  NaN
# 627                   1.0                  NaN                  NaN
# 202                   1.0                  NaN                  1.0
# 9                     4.0                  NaN                  NaN
#
#             curso_id  curso_busca      cidade_busca uf_busca  \
# 4     65899611932754     Medicina        Rio Branco       AC
# ...

# %%
#MENSALIDADES ENTRE 500 E MIL REAIS

df[(df['mensalidade'] > 500) & (df['mensalidade'] < 1000)].sample(5)
# Out:
#               grau              turno  mensalidade  bolsa_integral_cotas  \
# 15330  Bacharelado  Curso a Distância       593.60                   1.0
# 11238  Bacharelado            Noturno       775.00                   1.0
# 7502   Bacharelado            Noturno       979.98                   0.0
# 10935  Bacharelado            Noturno       792.50                   2.0
# 15452  Bacharelado  Curso a Distância       590.00                   NaN
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 15330                   NaN                  NaN                  NaN
# 11238                   1.0                  NaN                  1.0
# 7502                    7.0                  NaN                  NaN
# 10935                   1.0                  NaN                  NaN
# 15452                   NaN                  1.0                  NaN
#
#               curso_id                                    curso_busca  \
# ...

# %%
#CURSOS COM A MENSALIDADE MAIS CARA

df.nlargest(5, 'mensalidade')
# Out:
#           grau     turno  mensalidade  bolsa_integral_cotas  \
# 0  Bacharelado  Integral      9999.99                  15.0
# 1  Bacharelado   Noturno      9836.40                   1.0
# 2  Bacharelado  Integral      9715.61                   2.0
# 3  Bacharelado   Noturno      9689.34                   3.0
# 4  Bacharelado  Integral      9674.34                   4.0
#
#    bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 0                  14.0                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   5.0                  6.0                 10.0
# 3                   2.0                  NaN                  NaN
# 4                   1.0                  5.0                  2.0
#
#           curso_id curso_busca  cidade_busca uf_busca     cidade_filtro  \
# 0     706710394154    Medicina  Campo Grande       MS  NTAwMjAwNDAyNzA0
# ...

# %%
#CURSOS COM A MENSALIDADE MAIS BARATA

df.nsmallest(5, 'mensalidade')
# Out:
#                grau              turno  mensalidade  bolsa_integral_cotas  \
# 41444   Tecnológico         Vespertino        139.0                   1.0
# 41445   Bacharelado  Curso a Distância        139.0                   1.0
# 41446   Tecnológico  Curso a Distância        139.0                   3.0
# 41443   Tecnológico  Curso a Distância        144.0                   1.0
# 41172  Licenciatura  Curso a Distância        149.0                   1.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 41444                   NaN                  NaN                  NaN
# 41445                   NaN                  NaN                  NaN
# 41446                   1.0                  NaN                  NaN
# 41443                   2.0                  2.0                  5.0
# 41172                   NaN                  NaN                  NaN
#
#               curso_id                 curso_busca cidade_busca uf_busca  \
# ...
