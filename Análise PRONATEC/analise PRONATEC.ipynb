# %%
#Teste
import pandas as pd
from matplotllib import 
df = pd.read_csv('RedeFederal_Lista_Instituicoes_RFEPCT_2022.csv', encoding='utf-8')
# Substituições de caracteres corrompidos em todas as colunas que necessitam de correção

# %%
df.describe()
# Out:
#                ANO
# count   644.000000
# mean   2003.385093
# std      23.828068
# min    1888.000000
# 25%    2008.000000
# 50%    2010.000000
# 75%    2014.000000
# max    2022.000000

# %%
df.dtypes
# Out:
# SIGLA_INSTITUICAO                object
# NOME_INSTITUICAO                 object
# NOME_UNIDADE_ENSINO              object
# ANO                               int64
# SIGLA_UF_UNIDADE_ENSINO          object
# NOME_MUNICIPIO_UNIDADE_ENSINO    object
# dtype: object

# %%
df['SIGLA_UF_UNIDADE_ENSINO'].value_counts().plot(kind='barh', title='UF\'s com mais unidades de ensino PRONATEC', fontsize='13.0')
# Out:
# <Axes: title={'center': "UF's com mais unidades de ensino PRONATEC"}, ylabel='SIGLA_UF_UNIDADE_ENSINO'>

# %% [raw]
# df = df.replace({
#     'Ã¡': 'á',
#     'Ã©': 'é',
#     'Ã­': 'í',
#     'Ã³': 'ó',
#     'Ãº': 'ú',
#     'Ã¢': 'â',
#     'Ãª': 'ê',
#     'Ã´': 'ô',
#     'Ã§': 'ç',
#     'Ã£': 'ã',
#     'Ãµ': 'õ',
#     'Ãœ': 'ü',
#     'Ã‘': 'ñ',
#     'Â¿': 'ñ',
# })
